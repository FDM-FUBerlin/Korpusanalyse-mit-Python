# %% [markdown]
# # Überschrift
#
# ## Worum geht es?
#
# * Textdaten und Daten zu Texten in Python laden und mit Python auswerten
# * relevante Bibliotheken und Datenstrukturen
#     * NumPy: *Numerical Python*
#         * > "The fundamental package for scientific computing with Python" [cf. NumPy Homepage](https://numpy.org/)
#     * SciPy:
#         * > "an open-source software for mathematics, science, and engineering" [cf. SciPy Documentation](https://docs.scipy.org/doc/scipy/)
#     * Pandas:
#         * > ...

# %% [markdown]
# ## Background: Listen in Python

# %%
lint = [1, 2, 3, 4, 5]
lstr = ['Berlin', 'FU', 'Python']
lmix = ['Berlin', 'FU', 'Python', 5, 12, 2023, True, {'participants':10}] 
lint
# Out:
# [1, 2, 3, 4, 5]

# %%
lstr
# Out:
# ['Berlin', 'FU', 'Python']

# %%
[type(item) for item in lmix]
# Out:
# [str, str, str, int, int, int, bool, dict]

# %% [markdown]
# ## NumPy

# %%
import numpy as np

# %% [markdown]
# ### NumPy-Arrays

# %% [markdown]
# # Pandas

# %%
import pandas as pd
from os import listdir

# %%
inputDir = "Daten_EL/Dataframes/Deixis/"
a = listdir(inputDir)
a
# Out:
# ['Erbauungsbuch.csv', 'Gebetbuch.csv', 'Leichenpredigten.csv']

# %%
df1 = pd.read_csv(inputDir + 'Erbauungsbuch.csv', sep=';', na_values=".")
df1
# Out:
#                            file  date       ich        du       wir      ihr  \
# 0   felgenhauer_jehior_1640.xml  1640    514.52    477.77   4961.41   147.00
# 1      hecht_andachten_1668.xml  1668  28135.05  15943.19   4957.13  2344.59
# 2  luettkemann_harpffe_1674.xml  1674  12746.89   9604.17  10750.63  2363.33
# 3        santa_judas01_1686.xml  1686   6376.88   4928.97   1352.54  2475.32
# 4      schottel_hoelle_1676.xml  1676   1426.27   4032.47   2100.51   816.87
# 5  scriver_schaefflein_1672.xml  1672   7230.77   2720.63   3389.88  2720.63
# 6        spener_friede_1686.xml  1686   2411.14    797.23  19814.11  2080.58
#
#      ichWir     duIhr  meinPoss  deinPoss  unserPoss  euerPoss  ihrPOSS  \
# 0   5475.93    624.77    183.76     36.75    1102.54      0.00  2976.85
# 1  33092.18  18287.78  12593.78   9847.27    2813.50    535.91  3014.47
# 2  23497.53  11967.50   5958.61   4797.06    3248.32    422.38  3595.28
# 3   7729.42   7404.29   2059.16   1079.43     650.26    515.87  3671.80
# 4   3526.79   4849.33    518.65   1659.66    1970.85    259.32  2074.58
# 5  10620.65   5441.27   2196.87   1542.18    2138.68   1222.10  2938.87
# 6  22225.25   2877.81   1225.01    447.23    6397.29    505.56  3577.82
#
#    meinUnserPoss  deinEuerPoss  wirUnserPoss  1tePerson  2tePerson
# 0        1286.29         36.75       6063.95    6762.22     661.52
# 1       15407.29      10383.17       7770.63   48499.46   28670.95
# 2        9206.93       5219.44      13998.95   32704.45   17186.93
# 3        2709.42       1595.30       2002.80   10438.84    8999.60
# 4        2489.50       1918.99       4071.37    6016.29    6768.32
# 5        4335.55       2764.28       5528.56   14956.21    8205.55
# 6        7622.31        952.79      26211.40   29847.55    3830.60

# %%
df2 = pd.read_csv(inputDir + 'Leichenpredigten.csv', sep=';', na_values=".")
df2
# Out:
#          file  date      ich       du      wir      ihr    ichWir    duIhr  \
# 0  347551.xml  1650  9508.00  2112.89  8527.01   452.76  18035.01  2565.65
# 1  353338.xml  1678  5405.88  2179.79  5231.49  1743.83  10637.37  3923.62
# 2  354493.xml  1669  7476.64  1377.27  4426.96  6886.37  11903.59  8263.65
# 3  354527.xml  1672  4564.76  1592.36  8174.10  2441.61  12738.85  4033.97
# 4  354531.xml  1664  8158.67  2954.00  6189.34  2110.00  14348.01  5064.00
# 5  358833.xml  1686  7418.09  1820.18  5323.17  3193.90  12741.26  5014.08
# 6  359996.xml  1644  6310.51  4235.82  8730.98  1815.35  15041.49  6051.18
# 7  360677.xml  1659  8117.14  3302.56  4933.95  1750.76  13051.09  5053.32
# 8  509379.xml  1662  4878.05  3199.58  6556.52  1049.04  11434.57  4248.62
#
#    meinPoss  deinPoss  unserPoss  euerPoss   ihrPOSS  meinUnserPoss  \
# 0   5659.52   2641.11    2565.65     75.46   9357.08        8225.17
# 1   1656.64    959.11    3051.70   1220.68   4272.39        4708.34
# 2    590.26    590.26    2557.80   2951.30   4426.96        3148.06
# 3   1486.20    636.94    4140.13   1380.04  15817.41        5626.33
# 4   5767.34   1547.33    2672.67    140.67   6470.67        8440.01
# 5   4395.91   1545.44    4258.53    583.83  11676.63        8654.44
# 6   4495.16   2506.92    4408.71   1556.02  11151.45        8903.87
# 7   3183.19   1989.50    3063.82    517.27   2029.29        6247.02
# 8   2622.61   2045.63    4930.50    576.97   9546.29        7553.11
#
#    deinEuerPoss  wirUnserPoss  1tePerson  2tePerson
# 0       2716.57      11092.67   26260.19    5282.22
# 1       2179.79       8283.20   15345.71    6103.41
# 2       3541.56       6984.75   15051.65   11805.21
# 3       2016.99      12314.23   18365.18    6050.96
# 4       1688.00       8862.01   22788.02    6752.00
# 5       2129.27       9581.70   21395.70    7143.35
# 6       4062.93      13139.70   23945.37   10114.11
# 7       2506.76       7997.77   19298.11    7560.08
# 8       2622.61      11487.02   18987.67    6871.23

# %%
df3 = pd.read_csv(inputDir + 'Gebetbuch.csv', sep=';', na_values=".")
df3
# Out:
#                                      file  date       ich        du       wir  \
# 0              baumann_gebetbuch_1676.xml  1676   1568.36  25093.82  36464.46
# 1               deucer_gebetbuch_1665.xml  1665  26970.77  19216.92   8868.59
# 2               habermann_gebete_1659.xml  1659  26162.06  21831.09  11582.82
# 3            lohner_geistliche04_1684.xml  1684  32968.14  26957.48   4402.45
# 4  schwendendoerffer_andaechtige_1637.xml  1637  57344.51  24670.74   1858.97
# 5                zesen_gebetbuch_1660.xml  1660  31343.87  21723.04   8024.61
#
#        ihr    ichWir     duIhr  meinPoss  deinPoss  unserPoss  euerPoss  \
# 0   560.13  38032.82  25653.95    784.18  25709.96   19436.51    448.10
# 1  2268.94  35839.36  21485.86  14669.18  16050.27    5563.83    818.79
# 2   478.42  37744.88  22309.51  12841.82  20597.27    5816.59      0.00
# 3  2442.46  37370.59  29399.94  14875.87  16755.45    2663.58    663.38
# 4   598.65  59203.48  25269.39  31444.96  19755.50    1165.79     94.52
# 5  1393.06  39368.48  23116.10  18994.96  20968.47    4034.07    551.42
#
#    ihrPOSS  meinUnserPoss  deinEuerPoss  wirUnserPoss  1tePerson  2tePerson
# 0  1624.38       20220.69      26158.07      55900.97   58253.51   51812.02
# 1  1765.83       20233.01      16869.06      14432.42   56072.37   38354.92
# 2  3852.55       18658.41      20597.27      17399.41   56403.28   42906.78
# 3  2563.07       17539.45      17418.84       7066.04   54910.04   46818.78
# 4  1134.29       32610.75      19850.02       3024.77   91814.23   45119.42
# 5  2379.81       23029.04      21519.89      12058.68   62397.52   44635.99

# %%
import matplotlib.pyplot as plt

# %%
feat = '1tePerson'

# %%
fig = plt.boxplot([df1[feat], df2[feat], df3[feat]], 
                  showmeans=True, 
                  showfliers=True, 
                  notch=1, 
                  medianprops={'color': 'black'}, 
                  meanprops=dict(markerfacecolor='None', markeredgecolor='black'), 
                  patch_artist=True)

fig['boxes'][0].set_facecolor('#a9cce3')
fig['boxes'][1].set_facecolor('#d6eaf8')
fig['boxes'][2].set_facecolor('#edbb99')

plt.title('Merkmal: ' + str(feat), fontsize=14)
plt.xticks([1, 2, 3], ['Erbauungsbuch', 'Leichenpredigten', 'Gebetbuch'], fontsize=12, rotation=15)
plt.yticks(fontsize=12)
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 9
#       1 fig = plt.boxplot([df1[feat], df2[feat], df3[feat]],
#       2                   showmeans=True,
#       3                   showfliers=True,
#    (...)
#       6                   meanprops=dict(markerfacecolor='None', markeredgecolor='black'),
#       7                   patch_artist=True)
# ----> 9 fig['boxes'][0, 1, 2].set_facecolor('#a9cce3', '#d6eaf8', '#edbb99')
#      10 #fig['boxes'][1].set_facecolor()
#      11 #fig['boxes'][2].set_facecolor()
#      13 plt.title('Merkmal: ' + str(feat), fontsize=14)
#
# TypeError: list indices must be integers or slices, not tuple
